# %%
import pandas as pd
import plotnine as p9
from pathlib import Path
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotnine as p9

# %%
fitness = pd.read_table("../dnaid2023_fitness_d1.tab", sep=" ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-f325034cc8b0> in <module>
# ----> 1 fitness = pd.read_table("../dnaid2023_fitness_d1.tab", sep=" ")
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     682     kwds.update(kwds_defaults)
#     683
# --> 684     return _read(filepath_or_buffer, kwds)
#     685
#     686
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/miniconda3/envs/datavis/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dnaid2023_fitness_d1.tab'

# %%
fitness[fitness.baseMean > 1,]
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# AAAAAATCGCAGCCACT   764.464124       -0.120133  1.079292 -0.111307  0.911373
# AAAAAATTCCAGCGTCA   155.409365      -12.944776  4.892230 -2.645987  0.008145
# AAAAACAAACGCTAAGC  2050.053276       -0.156223  0.870130 -0.179540  0.857514
# AAAAACCCTTCTGCACC  1622.073651       -0.443084  0.423179 -1.047036  0.295083
# AAAAACCGCTGGATGGC     0.564575        2.837317  5.068829  0.559758  0.575645
#
#                        padj
# AAAAAATCGCAGCCACT  1.000000
# AAAAAATTCCAGCGTCA  0.582466
# AAAAACAAACGCTAAGC  1.000000
# AAAAACCCTTCTGCACC  0.965394
# AAAAACCGCTGGATGGC  0.965394

# %%
p9.options.figure_size = (10, 10)
(p9.ggplot(fitness, p9.aes(x='baseMean'))
 + p9.geom_histogram(bins=100)
 + p9.theme_classic())
# Out:
# <ggplot: (2985319125239)>

# %%
p9.options.figure_size = (10, 10)
(p9.ggplot(fitness, p9.aes(x='baseMean', y='lfcSE'))
 + p9.geom_point()
 + p9.theme_classic()
)
# Out:
# <ggplot: (2985328168554)>

# %%
p9.options.figure_size = (10, 10)
(p9.ggplot(fitness, p9.aes(x='lfcSE'))
 + p9.geom_histogram(bins=100)
 + p9.theme_classic())
# Out:
# <ggplot: (2985318676218)>

# %%
p9.options.figure_size = (10, 10)
(p9.ggplot(fitness, p9.aes(x='log2FoldChange', y='baseMean'))
 + p9.geom_point()
 + p9.theme_classic()

)
# Out:
# <ggplot: (2985328083453)>
